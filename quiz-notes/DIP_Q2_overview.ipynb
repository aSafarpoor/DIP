# %% [markdown]
# <a href="https://colab.research.google.com/github/aSafarpoor/DIP/blob/main/quiz-notes/DIP_Q2_overview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # some definitions

# %% [markdown]
# **Luminous vs Luminance vs Illuminance**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * **brightness** is dependent on surrounding.
# * **luminance** is about a point and independent from surrounding.

# %% [markdown]
# Intensity:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Mach bands** is an optical illusion named after the physicist Ernst Mach. It exaggerates the contrast between edges of the slightly differing shades of gray, as soon as they contact one another, by triggering edge-detection in the human visual system.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# What is **spatial frequency domain** in image processing?
# In spatial domain, we deal with images as it is. In frequency domain, we deal with the rate at which the pixel values are changing in spatial domain. Input image→Processing→Output image matrix.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **MTF:**
#
# The **modulation transfer function (MTF)** determines how much contrast in the original object is maintained by the detector. In other words, it characterizes how faithfully the spatial frequency content of the object gets transferred to the image.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **HVS: Human visual system**
#
# * more sensetive in middle frequencies
# * more sensetive to edges
# * less sensetive to crowed high detailed parts
#
# ------
# **Human vision attributes:**
# * color
# * motion
# * shape --> more important than color
# * depth

# %% [markdown]
# # color representation systems

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Cyan: فیروزه‌ای
#
# Magenrtia: ارغوانی

# %% [markdown]
# ## HSV:
# * Hue
# * Saturation
# * Value
#
# ![image.png](data:image/png;base64,...)

# %%
import colorsys
print(colorsys.rgb_to_hsv(.3, .4, .2))
print(colorsys.hsv_to_rgb(0.25, 0.5, 0.4))
# Out:
# (0.25, 0.5, 0.4)
# (0.30000000000000004, 0.4, 0.2)

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## conversion

# %% [markdown]
# **Good site with all of formula:**
#
# https://www.rapidtables.com/convert/color/hsv-to-rgb.html
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## Different systems

# %% [markdown]
# **HSL , HSV:**
# https://programmingdesignsystems.com/color/color-models-and-color-spaces/index.html

# %% [markdown]
# **CYM, CYMK**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **YUV**
#
# YUV is a color model typically used as part of a color image pipeline. It encodes a color image or video taking human perception into account, allowing reduced bandwidth for chrominance components, compared to a "direct" RGB-representation.
#
# good reference: https://softpixel.com/~cwright/programming/colorspace/yuv/
#
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **HMMD**
# A new color model HMMD is disclosed based upon hue, the shade, the tone, the tint and the brightness of a color, and a color quantizing method using the HMMD color space. The present invention regards the colors adjacent to a given color in the color space as the neighboring colors to consider indices of the neighboring colors as the partial values according to the distance. Accordingly, the present invention can accomplish a color quantization close to the change of the color sensed by the human eye, thereby capable of enhancing a performance of the image searching system based on content.

# %% [markdown]
# **Commission Internationale de l’Elcairage (CIE)**
# good source: https://www.techopedia.com/definition/477/cie-color-model

# %% [markdown]
# # references:
# 1. All images are from internet.
#
# 2. Most texts are from internet.
